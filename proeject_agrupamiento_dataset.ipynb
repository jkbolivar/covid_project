# %% [markdown]
# <a href="https://colab.research.google.com/github/jkbolivar/covid_project/blob/main/proeject_agrupamiento_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Llamamos el set de datos público 
Chicago_data = 'https://raw.githubusercontent.com/terranigmark/curso-analisis-exploratorio-datos-platzi/main/Traffic_Crashes1.csv'

# %%
import pandas as pd
Chicago_df=pd.read_csv(Chicago_data)
import altair as alt

# %%
Chicago_df['CRASH_DATE']=Chicago_df['CRASH_DATE'].apply(lambda x: pd.to_datetime(x,errors='coerce', utc=True))

# %%
Chicago_df.groupby(['LIGHTING_CONDITION','REPORT_TYPE','CRASH_HOUR']).agg({'BEAT_OF_OCCURRENCE':'sum',})
# Out:
#                                                           BEAT_OF_OCCURRENCE
# LIGHTING_CONDITION REPORT_TYPE                CRASH_HOUR
# DARKNESS           AMENDED                    20                      1614.0
#                    NOT ON SCENE (DESK REPORT) 0                      64739.0
#                                               1                      60086.0
#                                               2                      36251.0
#                                               3                      39172.0
# ...                                                                      ...
# UNKNOWN            ON SCENE                   19                      4735.0
#                                               20                      8113.0
#                                               21                      6122.0
#                                               22                      9699.0
#                                               23                      3176.0
#
# [291 rows x 1 columns]

# %%
Chicago_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27961 entries, 0 to 27960
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     27961 non-null  int64
#  1   CRASH_RECORD_ID                27961 non-null  object
#  2   RD_NO                          27713 non-null  object
#  3   CRASH_DATE_EST_I               2117 non-null   object
#  4   CRASH_DATE                     27961 non-null  datetime64[ns, UTC]
#  5   POSTED_SPEED_LIMIT             27961 non-null  int64
#  6   TRAFFIC_CONTROL_DEVICE         27961 non-null  object
#  7   DEVICE_CONDITION               27961 non-null  object
#  8   WEATHER_CONDITION              27961 non-null  object
#  9   LIGHTING_CONDITION             27961 non-null  object
#  10  FIRST_CRASH_TYPE               27961 non-null  object
#  11  TRAFFICWAY_TYPE                27961 non-null  object
#  12  LANE_CNT                       12418 non-null  float64
#  13  ALIGNMENT                      27961 non-null  object
#  14  ROADWAY_SURFACE_COND           27961 non-null  object
#  15  ROAD_DEFECT                    27961 non-null  object
#  16  REPORT_TYPE                    27294 non-null  object
#  17  CRASH_TYPE                     27961 non-null  object
#  18  INTERSECTION_RELATED_I         6155 non-null   object
#  19  NOT_RIGHT_OF_WAY_I             1356 non-null   object
#  20  HIT_AND_RUN_I                  7952 non-null   object
#  21  DAMAGE                         27961 non-null  object
#  22  DATE_POLICE_NOTIFIED           27961 non-null  object
#  23  PRIM_CONTRIBUTORY_CAUSE        27961 non-null  object
#  24  SEC_CONTRIBUTORY_CAUSE         27961 non-null  object
#  25  STREET_NO                      27961 non-null  int64
#  26  STREET_DIRECTION               27960 non-null  object
#  27  STREET_NAME                    27961 non-null  object
#  28  BEAT_OF_OCCURRENCE             27960 non-null  float64
#  29  PHOTOS_TAKEN_I                 341 non-null    object
#  30  STATEMENTS_TAKEN_I             564 non-null    object
#  31  DOORING_I                      99 non-null     object
#  32  WORK_ZONE_I                    158 non-null    object
#  33  WORK_ZONE_TYPE                 125 non-null    object
#  34  WORKERS_PRESENT_I              41 non-null     object
#  35  NUM_UNITS                      27961 non-null  int64
#  36  MOST_SEVERE_INJURY             27908 non-null  object
#  37  INJURIES_TOTAL                 27910 non-null  float64
#  38  INJURIES_FATAL                 27910 non-null  float64
#  39  INJURIES_INCAPACITATING        27910 non-null  float64
#  40  INJURIES_NON_INCAPACITATING    27910 non-null  float64
#  41  INJURIES_REPORTED_NOT_EVIDENT  27910 non-null  float64
#  42  INJURIES_NO_INDICATION         27910 non-null  float64
#  43  INJURIES_UNKNOWN               27910 non-null  float64
#  44  CRASH_HOUR                     27961 non-null  int64
#  45  CRASH_DAY_OF_WEEK              27961 non-null  int64
#  46  CRASH_MONTH                    27961 non-null  int64
#  47  LATITUDE                       27800 non-null  float64
#  48  LONGITUDE                      27800 non-null  float64
#  49  LOCATION                       27800 non-null  object
#  50  date_real                      27961 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(11), int64(7), object(32)
# memory usage: 10.9+ MB

# %%
Chicago_df.head()
# Out:
#    Unnamed: 0                                    CRASH_RECORD_ID     RD_NO  \
# 0      290702  9e97e92753166de921a0e87199513aa841142c6fbb3a1e...  JA154528
# 1      405524  e5fe82ab7757d630a7f79927113bc63b5bede0cda74665...  JC391213
# 2      261834  8c8ea6db9e1950765419429e2732ba5598fc6f87ac9e0c...  JC273287
# 3       38519  02671b7d36a9d189d607778816fec23bbb2e5ac3cd3039...  JA307115
# 4      420197  ef1b1d450f65c6d16245dffdd3304d93b8be7d7bbf47f3...  JB247942
#
#   CRASH_DATE_EST_I                CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0              NaN 2017-02-14 10:00:00+00:00                  30
# 1              NaN 2019-08-13 19:12:00+00:00                  35
# 2              NaN 2019-05-22 08:30:00+00:00                  25
# 3              NaN 2017-06-14 16:50:00+00:00                   0
# 4              NaN 2018-05-03 08:35:00+00:00                  30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0            NO CONTROLS           NO CONTROLS             CLEAR
# 1         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 2      STOP SIGN/FLASHER  FUNCTIONING PROPERLY              RAIN
# 3                UNKNOWN               UNKNOWN           UNKNOWN
# 4            NO CONTROLS           NO CONTROLS              RAIN
#
#   LIGHTING_CONDITION  ... INJURIES_REPORTED_NOT_EVIDENT  \
# 0           DAYLIGHT  ...                           0.0
# 1           DAYLIGHT  ...                           0.0
# 2           DAYLIGHT  ...                           0.0
# 3            UNKNOWN  ...                           0.0
# 4           DAYLIGHT  ...                           0.0
#
#   INJURIES_NO_INDICATION  INJURIES_UNKNOWN CRASH_HOUR CRASH_DAY_OF_WEEK  \
# 0                    1.0               0.0         10                 3
# 1                    8.0               0.0         19                 3
# 2                    2.0               0.0          8                 4
# 3                    2.0               0.0         16                 4
# 4                    2.0               0.0          8                 5
#
#   CRASH_MONTH   LATITUDE  LONGITUDE                                  LOCATION  \
# 0           2  42.001676 -87.666364  POINT (-87.666364005301 42.001675862416)
# 1           8  41.940041 -87.650923  POINT (-87.650923222567 41.940040917032)
# 2           5  41.955854 -87.710645  POINT (-87.710644534923 41.955853610383)
# 3           6  41.863734 -87.676313  POINT (-87.676312689993 41.863734390899)
# 4           5  41.851794 -87.695223  POINT (-87.695223114296 41.851794251516)
#
#     date_real
# 0  2017-02-14
# 1  2019-08-13
# 2  2019-05-22
# 3  2017-06-14
# 4  2018-05-03
#
# [5 rows x 51 columns]

# %%
light_condition_per=Chicago_df.groupby(['LIGHTING_CONDITION','REPORT_TYPE','CRASH_HOUR']).agg({'BEAT_OF_OCCURRENCE':'sum',})

# %%
light_condition_per=light_condition_per.reset_index()

# %%
light_condition_per.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   LIGHTING_CONDITION  291 non-null    object
#  1   REPORT_TYPE         291 non-null    object
#  2   CRASH_HOUR          291 non-null    int64
#  3   BEAT_OF_OCCURRENCE  291 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 9.2+ KB

# %%
import altair as alt

# %%
Chicago_df.groupby(['LIGHTING_CONDITION','REPORT_TYPE']).agg({'CRASH_HOUR':'mean'})
# Out:
#                                                    CRASH_HOUR
# LIGHTING_CONDITION     REPORT_TYPE
# DARKNESS               AMENDED                      20.000000
#                        NOT ON SCENE (DESK REPORT)   15.395450
#                        ON SCENE                     13.735294
# DARKNESS, LIGHTED ROAD AMENDED                      22.000000
#                        NOT ON SCENE (DESK REPORT)   15.688938
#                        ON SCENE                     12.978808
# DAWN                   NOT ON SCENE (DESK REPORT)   11.816733
#                        ON SCENE                      9.266968
# DAYLIGHT               AMENDED                      11.923077
#                        NOT ON SCENE (DESK REPORT)   12.749100
#                        ON SCENE                     12.275000
# DUSK                   AMENDED                      20.000000
#                        NOT ON SCENE (DESK REPORT)   16.787321
#                        ON SCENE                     16.905775
# UNKNOWN                NOT ON SCENE (DESK REPORT)   12.798440
#                        ON SCENE                     10.393782

# %%
Chicago_df.groupby(['LIGHTING_CONDITION','REPORT_TYPE']).agg({'CRASH_HOUR':['mean','min','max']})
# Out:
#                                                   CRASH_HOUR
#                                                         mean min max
# LIGHTING_CONDITION     REPORT_TYPE
# DARKNESS               AMENDED                     20.000000  20  20
#                        NOT ON SCENE (DESK REPORT)  15.395450   0  23
#                        ON SCENE                    13.735294   0  23
# DARKNESS, LIGHTED ROAD AMENDED                     22.000000  21  23
#                        NOT ON SCENE (DESK REPORT)  15.688938   0  23
#                        ON SCENE                    12.978808   0  23
# DAWN                   NOT ON SCENE (DESK REPORT)  11.816733   0  22
#                        ON SCENE                     9.266968   0  23
# DAYLIGHT               AMENDED                     11.923077   6  20
#                        NOT ON SCENE (DESK REPORT)  12.749100   0  23
#                        ON SCENE                    12.275000   0  22
# DUSK                   AMENDED                     20.000000  20  20
#                        NOT ON SCENE (DESK REPORT)  16.787321   0  23
#                        ON SCENE                    16.905775   0  23
# UNKNOWN                NOT ON SCENE (DESK REPORT)  12.798440   0  23
#                        ON SCENE                    10.393782   0  23

# %%
crash_hours_reporte=Chicago_df.groupby(['LIGHTING_CONDITION','REPORT_TYPE']).agg({'CRASH_HOUR':['mean','min','max'],'CRASH_RECORD_ID':'count'})

# %%
crash_hours_reporte=crash_hours_reporte.reset_index()

# %%
crash_hours_reporte.head()
# Out:
#        LIGHTING_CONDITION                 REPORT_TYPE CRASH_HOUR          \
#                                                             mean min max
# 0                DARKNESS                     AMENDED  20.000000  20  20
# 1                DARKNESS  NOT ON SCENE (DESK REPORT)  15.395450   0  23
# 2                DARKNESS                    ON SCENE  13.735294   0  23
# 3  DARKNESS, LIGHTED ROAD                     AMENDED  22.000000  21  23
# 4  DARKNESS, LIGHTED ROAD  NOT ON SCENE (DESK REPORT)  15.688938   0  23
#
#   CRASH_RECORD_ID
#             count
# 0               1
# 1             923
# 2             510
# 3               3
# 4            2694

# %%
crash_hours_reporte.columns
# Out:
# MultiIndex([('LIGHTING_CONDITION',      ''),
#             (       'REPORT_TYPE',      ''),
#             (        'CRASH_HOUR',  'mean'),
#             (        'CRASH_HOUR',   'min'),
#             (        'CRASH_HOUR',   'max'),
#             (   'CRASH_RECORD_ID', 'count')],
#            )

# %%
new_column_names=['LIGHTING_CONDITION','REPORT_TYPE','CRASH_HOUR_mean','CRASH_HOUR_min','CRASH_HOUR_max','count_id']

# %%
 crash_hours_reporte.columns = new_column_names

# %%
alt.Chart(crash_hours_reporte).mark_bar().encode(
    x='LIGHTING_CONDITION',
    y='count_id',
    color='REPORT_TYPE'
).properties(width=220)
# Out:
# alt.Chart(...)

# %%
Chicago_df.groupby(['LIGHTING_CONDITION','REPORT_TYPE']).agg({'CRASH_HOUR':['mean','min','max','std','var']})
# Out:
#                                                   CRASH_HOUR          \
#                                                         mean min max
# LIGHTING_CONDITION     REPORT_TYPE
# DARKNESS               AMENDED                     20.000000  20  20
#                        NOT ON SCENE (DESK REPORT)  15.395450   0  23
#                        ON SCENE                    13.735294   0  23
# DARKNESS, LIGHTED ROAD AMENDED                     22.000000  21  23
#                        NOT ON SCENE (DESK REPORT)  15.688938   0  23
#                        ON SCENE                    12.978808   0  23
# DAWN                   NOT ON SCENE (DESK REPORT)  11.816733   0  22
#                        ON SCENE                     9.266968   0  23
# DAYLIGHT               AMENDED                     11.923077   6  20
#                        NOT ON SCENE (DESK REPORT)  12.749100   0  23
#                        ON SCENE                    12.275000   0  22
# DUSK                   AMENDED                     20.000000  20  20
#                        NOT ON SCENE (DESK REPORT)  16.787321   0  23
#                        ON SCENE                    16.905775   0  23
# UNKNOWN                NOT ON SCENE (DESK REPORT)  12.798440   0  23
#                        ON SCENE                    10.393782   0  23
#
#
#                                                         std        var
# LIGHTING_CONDITION     REPORT_TYPE
# DARKNESS               AMENDED                          NaN        NaN
#                        NOT ON SCENE (DESK REPORT)  7.640134  58.371650
#                        ON SCENE                    8.447837  71.365942
# DARKNESS, LIGHTED ROAD AMENDED                     1.000000   1.000000
#                        NOT ON SCENE (DESK REPORT)  7.716604  59.545982
#                        ON SCENE                    9.104244  82.887262
# DAWN                   NOT ON SCENE (DESK REPORT)  5.945610  35.350279
#                        ON SCENE                    5.634007  31.742040
# DAYLIGHT               AMENDED                     4.386752  19.243590
#                        NOT ON SCENE (DESK REPORT)  3.530387  12.463629
#                        ON SCENE                    3.560642  12.678174
# DUSK                   AMENDED                     0.000000   0.000000
#                        NOT ON SCENE (DESK REPORT)  3.754746  14.098118
#                        ON SCENE                    3.957888  15.664875
# UNKNOWN                NOT ON SCENE (DESK REPORT)  6.077597  36.937185
#                        ON SCENE                    6.799997  46.239961

# %%
Chicago_df.groupby(['DATE_POLICE_NOTIFIED']).groups.keys()
# Out:
# dict_keys(['01/01/2017 01:20:00 AM', '01/01/2017 01:54:00 AM', '01/01/2017 02:35:00 PM', '01/01/2017 04:50:00 AM', '01/01/2017 09:15:00 PM', '01/01/2017 09:48:00 AM', '01/01/2017 11:17:00 PM', '01/01/2018 01:40:00 PM', '01/01/2018 02:40:00 PM', '01/01/2018 02:42:00 AM', '01/01/2018 02:47:00 AM', '01/01/2018 02:47:00 PM', '01/01/2018 03:00:00 AM', '01/01/2018 04:50:00 PM', '01/01/2018 06:20:00 PM', '01/01/2018 06:33:00 AM', '01/01/2018 07:00:00 PM', '01/01/2018 07:12:00 PM', '01/01/2018 07:30:00 PM', '01/01/2018 08:45:00 PM', '01/01/2018 09:35:00 AM', '01/01/2018 09:40:00 PM', '01/01/2018 10:15:00 PM', '01/01/2018 11:30:00 AM', '01/01/2018 12:25:00 PM', '01/01/2018 12:32:00 AM', '01/01/2018 12:40:00 AM', '01/01/2018 12:55:00 PM', '01/01/2019 01:15:00 AM', '01/01/2019 02:25:00 AM', '01/01/2019 02:34:00 PM', '01/01/2019 02:35:00 AM', '01/01/2019 02:45:00 PM', '01/01/2019 02:57:00 AM', '01/01/2019 03:23:00 AM', '01/01/2019 03:47:00 AM', '01/01/2019 04:00:00 PM', '01/01/2019 05:31:00 PM', '01/01/2019 05:36:00 AM', '01/01/2019 05:57:00 PM', '01/01/2019 06:40:00 AM', '01/01/2019 07:15:00 PM', '01/01/2019 10:19:00 PM', '01/01/2019 10:27:00 PM', '01/01/2019 11:10:00 PM', '01/01/2019 12:07:00 AM', '01/01/2019 12:10:00 PM', '01/01/2019 12:30:00 AM', '01/01/2020 01:05:00 PM', '01/01/2020 02:14:00 PM', '01/01/2020 02:17:00 AM', '01/01/2020 03:05:00 AM', '01/01/2020 03:10:00 AM', '01/01/2020 03:41:00 PM', '01/01/2020 04:04:00 PM', '01/01/2020 04:26:00 AM', '01/01/2020 05:01:00 PM', '01/01/2020 05:08:00 AM', '01/01/2020 05:10:00 AM', '01/01/2020 06:04:00 AM', '01/01/2020 06:20:00 PM', '01/01/2020 07:00:00 PM', '01/01/2020 08:05:00 AM', '01/01/2020 09:45:00 PM', '01/01/2020 10:01:00 AM', '01/01/2020 10:45:00 PM', '01/01/2020 12:00:00 AM', '01/01/2020 12:45:00 PM', '01/02/2016 02:30:00 PM', '01/02/2016 02:50:00 PM', '01/02/2016 05:42:00 PM', '01/02/2016 12:29:00 AM', '01/02/2017 01:26:00 AM', '01/02/2017 03:30:00 PM', '01/02/2017 08:34:00 PM', '01/02/2017 10:15:00 PM', '01/02/2017 10:35:00 AM', '01/02/2017 10:43:00 AM', '01/02/2018 01:00:00 PM', '01/02/2018 02:20:00 PM', '01/02/2018 02:41:00 PM', '01/02/2018 02:50:00 PM', '01/02/2018 03:20:00 PM', '01/02/2018 03:30:00 PM', '01/02/2018 03:35:00 PM', '01/02/2018 03:57:00 PM', '01/02/2018 04:02:00 PM', '01/02/2018 04:05:00 PM', '01/02/2018 04:10:00 PM', '01/02/2018 05:10:00 PM', '01/02/2018 05:38:00 AM', '01/02/2018 06:00:00 PM', '01/02/2018 06:02:00 PM', '01/02/2018 06:20:00 AM', '01/02/2018 06:29:00 PM', '01/02/2018 06:47:00 AM', '01/02/2018 07:00:00 PM', '01/02/2018 08:24:00 AM', '01/02/2018 08:34:00 AM', '01/02/2018 08:45:00 AM', '01/02/2018 08:45:00 PM', '01/02/2018 08:55:00 AM', '01/02/2018 09:00:00 AM', '01/02/2018 11:00:00 AM', '01/02/2018 11:14:00 AM', '01/02/2018 11:15:00 AM', '01/02/2018 11:37:00 PM', '01/02/2018 12:54:00 PM', '01/02/2019 01:43:00 PM', '01/02/2019 02:00:00 PM', '01/02/2019 02:15:00 PM', '01/02/2019 02:55:00 PM', '01/02/2019 03:00:00 PM', '01/02/2019 04:40:00 PM', '01/02/2019 06:15:00 PM', '01/02/2019 06:25:00 PM', '01/02/2019 09:11:00 AM', '01/02/2019 09:30:00 PM', '01/02/2019 10:05:00 PM', '01/02/2019 10:09:00 PM', '01/02/2019 11:45:00 AM', '01/02/2020 01:15:00 AM', '01/02/2020 01:52:00 PM', '01/02/2020 02:50:00 PM', '01/02/2020 03:10:00 PM', '01/02/2020 03:15:00 PM', '01/02/2020 04:42:00 PM', '01/02/2020 05:15:00 PM', '01/02/2020 05:54:00 PM', '01/02/2020 06:30:00 PM', '01/02/2020 07:08:00 PM', '01/02/2020 07:45:00 PM', '01/02/2020 08:15:00 PM', '01/02/2020 08:16:00 AM', '01/02/2020 08:40:00 PM', '01/02/2020 09:05:00 AM', '01/02/2020 10:09:00 PM', '01/02/2020 10:15:00 AM', '01/02/2020 10:26:00 PM', '01/02/2020 10:27:00 PM', '01/02/2020 10:37:00 PM', '01/02/2020 11:38:00 AM', '01/02/2020 12:10:00 AM', '01/02/2020 12:20:00 PM', '01/02/2020 12:31:00 PM', '01/02/2020 12:58:00 AM', '01/03/2016 01:10:00 PM', '01/03/2016 02:26:00 PM', '01/03/2016 04:53:00 PM', '01/03/2016 08:15:00 PM', '01/03/2016 08:20:00 PM', '01/03/2017 02:05:00 PM', '01/03/2017 02:54:00 PM', '01/03/2017 ...

# %%
Chicago_df.groupby(['LIGHTING_CONDITION','REPORT_TYPE'])['CRASH_RECORD_ID'].count()
# Out:
# LIGHTING_CONDITION      REPORT_TYPE
# DARKNESS                AMENDED                           1
#                         NOT ON SCENE (DESK REPORT)      923
#                         ON SCENE                        510
# DARKNESS, LIGHTED ROAD  AMENDED                           3
#                         NOT ON SCENE (DESK REPORT)     2694
#                         ON SCENE                       3020
# DAWN                    NOT ON SCENE (DESK REPORT)      251
#                         ON SCENE                        221
# DAYLIGHT                AMENDED                          13
#                         NOT ON SCENE (DESK REPORT)    11116
#                         ON SCENE                       6760
# DUSK                    AMENDED                           2
#                         NOT ON SCENE (DESK REPORT)      489
#                         ON SCENE                        329
# UNKNOWN                 NOT ON SCENE (DESK REPORT)      769
#                         ON SCENE                        193
# Name: CRASH_RECORD_ID, dtype: int64
